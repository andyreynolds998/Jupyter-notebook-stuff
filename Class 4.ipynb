# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def search(self, target): # our target param represents the data were looking for
        current = self.head # we initialize 'current' at the head of our list
        found = False # create a boolean variable 'found' that represents the search state
        while current: # loop as long as current is not none (see nonetype)
            if current.data == target: # if the node references by 'current'has the data were looking for, set found to true and
                found = True           # ... exit the loop 
                break
            current = current.next # otherwise current will point to the next node in our list
        return found # our method returns whatever value 'found' has
    
# 1. create a method for our LinkedList class that returns the index of a target value if it exists in the list
# the method should be called 'index'
# 2. create a method for our LinkedList class that returns the value at a given index if the index exists
# the method should be called data_at

    def prepend(self, data):
        # create a node with the incoming data:
        node = Node(data)
        # store a temporary reference to our current 'head'
        current_head = self.head
        #set self.head so that it points to 'node':
        self.head = node
        # link our 'node' at self.head to 'current_head' thus linking it to the rest of our list:
        self.head.next = current.head

#    def append(self, data):
#       if not self.head:
#            self.head = Node(data)
#        else:
#            current = self.head
#            while current.next:
#                current = current.next
#            current.next = Node(data)
            
    def get_tail(self):
        if not self.head
            return None
        current = self.head
        while current.next:
            current = current.next
        self.tail = current
        return self.tail
    
    def append(self, data):
        current = self.get_tail()
        if not current:
            self.head = Node(data)
            self.tail = self.head
        else:
            current.next = Node(data)
            self.tail = current.next
            
    def insert(self, index_after, data):
        tail = self.get_tail()
        if not current:
            raise Exception("Reference to head not set")
        current = self.head
        current_index = 0
        while current:
            if current_index == index_after:
                new_node = node(data)
                current.next = new_node
                if new_node.next == None:
                    self.tail = new_node
                break
            current = current.next
            current_index += 1
        raise Exception("Index out of bounds")
        
    def remove(self, target):
        tail = self.get_tail()
        if not self.head:
            raise Exception("reference to head not set")
        current = self.head
        found = False
        if current.data == target:
            self.head = self.head.next
        while current.next:
            previous = current
            current = current.next
            if current.data == target:
                previous.next = current.next
                found = True
                if previous.next == None:
                    self.tail = previous
            if not found:
                raise Exception("Target not in list")
                
        def __str__(self):
            current = self.head
            out = ""
            while current:
                out += "%d, " % current.data
                current = current.next
            return "[%s]" % out
# Out:
#   File "/tmp/ipykernel_173/3986269140.py", line 45
#     if not self.head
#                     ^
# SyntaxError: invalid syntax

# %%
class DNode:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
class DLlist:
    def __init__(self, data):
        self.head = None
        
    def append(self, data):
        if not self.head:
            self.head = DNode(data)
        else:
            current = self.head
        while current:
                current = current.next
            new_node = DNode(data)
            current.next = new_node
            new_node.prev = current
                
    def remove_last(self, data):
        tail = self.tail()
        current = self.head
        if not self.head:
            return False        
        if current.data == data:
            self.head = self.head.next
            self.head.prev = None
            return True
        while current.next:
            previous = current
            current = current.next
        if current.data == data:
            previous.next = current.next
            found = True
        if previous.next == None:
            self.tail = previous
        if not found:
            return current data
# Out:
#   File "<tokenize>", line 18
#     new_node = DNode(data)
#     ^
# IndentationError: unindent does not match any outer indentation level
